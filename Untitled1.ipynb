# %%
#5. Leer un número entero y determinar el número de cincos que están 
#consecutivos en un número.
# Por ejemplo, en 5512355551 hay 6 cincos consecutivos. Ahora, en
# 234555234512 solo hay 3 cincos consecutivos.
import math
try:
    numero = int(input("Ingresa un numero entero: "))

  # longitud del numero
    longitud = int((math.log10(numero) + 1))
    print("numero de digitos:", int((math.log10(numero) + 1)))
    contador = 0
    num1 = 0
    num2 = 0
    suma = 0

    digito4 = (int(numero % 10))
    digito3 = (int(numero % 10)) #resultado define el valor y compara 
    digito2 = int(int(numero / 10) % 10)
    digito1 = (int(round(numero / 10) / 10))

    for num in range(1, longitud + 1):
        contador += 1
        print("digitos:", list(map(int, str(numero)[contador - 1])))
        num1 = list(map(int, str(numero)[contador - 1]))
        num2 = list(map(int, str(numero)[contador - 2]))
        if num2 == num1:
            suma += 1

    print("suma digitos iguales consecutivos es :", round(suma + (suma / 2),0))

except:
    print("Verifique los datos ingresados")

# %%
#17Leer una lista y determinar cuál es el segundo elemento más grande de dicha 
#lista. No utilice ningún tipo de algoritmo de ordenamiento para realizar este 
#ejercicio.  
Solo_Enteros = False

def Leer_L() :
    '''Lee un elemento y corrobora que este sea una lista. 
    '''
    while True   :
        try      :
            L= eval(input('Ingrese una lista: '))
            if type(L) is list:
                break
            else :
                print('El elemento ingresado debe ser una lista.\
 Intentelo de nuevo.')
        except SyntaxError :
            print('El elemento ingresado debe ser una lista.\
 Intentelo de nuevo.')
    return L
#%%
# Funcion que comprueba que una lista tenga solo enteros
def L_Enteros(L) :
    ''' Comprueba que todos los elementos de una lista sean enteros.
    '''
    for Elem in L:
        if type(Elem) is int:
            X = True
        else :
            X= False
            break
    return X
#%%
    
# Este solicita la lista  solo numeros enteros

while True:
    if Solo_Enteros == False:
        L = Leer_L()
        Solo_Enteros = L_Enteros(L)
        if Solo_Enteros == False:
            print('La lista debe contener solo numeros enteros.\
intentelo de nuevo.')
    else: break

print()
print('La lista es: ')
print(L)
print()
V_1 = L[0]           
for i in L :        # el ciclo for comparara cada elemento con
    if i > V_1 :    #este, si encuentra un elemento mayor  este
        V_1 = i     #pasara a ser M.
                        
while V_1 in L:     #se remueve solo un elemento                  
    L.remove(V_1)   
if L== [] :                           
    print('Todos los elementos de la lista son iguales.')    
                                           
#si esto pasa eliminan todos los elementos 
    
else:                   #Se repite el mismo proceso  hasta  hallar el mayor
    V_2 = L[0]      
    for j in L :    
            V_2 = j         
    print(f'El segundo elemento mayor de la lista es:',V_2)

# %%
#18. Leer una matriz cuadrada A, obtener su matriz triangular superior 
#asociada U y determinar qué fila de U contiene la
#mayor cantidad de unos.Asegurar que cumpla la definicion de matriz.
    
while True:
    try   :
        Matriz = eval(input('Ingrese la matriz cuadrada: '))
        
        # Comprueba que el elemento ingresado sea una lista
        if type(Matriz) is list :
            
            # Revisara que sea una lita .
            for Fila in Matriz:
                if type(Fila) is list:
                    
                    # Revisara cada elemento o "entrada" de cada fila
                    #sea un entero 
                    
                    for Entrada in Fila:
                        
                        if type(Entrada) is not int: raise Exception
            # Error si no es lista 
                else: raise Exception
        
        else: raise Exception
    
        # Toma la primera fila de la matriz como referencia, y se asegura 
        # de que todas las fila tengan la misma longitud que esta.
        for Fila in Matriz:
            if len(Fila) != len(Matriz[0]) : raise Exception
        
        # Si todo lo anterior sucede sin errores interrumpe el ciclo while.
        break
    
    except Exception:
        print('Alguno de los elementos de la matriz no cumple con \
la definicion de matriz. Revise su matriz e intentelo de nuevo.')
    
 
    
x=-1 #contador para que que indice de la fila aumente en 1, para conservar
#patron tirangular

for i in range(0,len(Matriz)): #Se creará un ciclo for para cambiar los índices
#debajo de la diagonal por ceros
    x+=1                                #i = columnas
    for j in range(1+x,len(Matriz)):         #j = filas
        Matriz[j][i]=0
print('La matriz triangular superior es:',Matriz)

# %%
#PUNTO 19. Leer una lista e identifique la sublista más larga dentro de dicha
#lista que se encuentra ordenada ascendentemente.


while True: # asegura que se digite una lista
    try: 
        Lista1=eval(input('Ingrese una lista: ')) 
        if type(Lista1) == list:
            for i in Lista1:
                if type(i) == int:
                    continue
                else: raise Exception
            break
        else: raise Exception
    except Exception: print('El elemento ingresado debe ser una lista de\
 numeros enteros')
    
    
Lista1.append(0)
l= 0
Lista2 = [[]]
for i in range(0,len(Lista1)-1): #Evalúa el índice i con el siguiente comparando
#si el #segundo es mayor que el primero, sucediendo esto, se agregará a una 
#sublista
    if Lista1[i] <= Lista1[i+1]:
        Lista2[l].append(Lista1[i])
    else:
        Lista2[l].append(Lista1[i])
        l+= 1
        Lista2.append([]) #Cuando se llegue a un número que no cumpla esta 
#condición, se agrega una nueva sublista vacía y el programa seguirá iterando
#buscando el mismo patrón 
       
Lista3=[]

for i in Lista2:
    Lista3.append(len(i))
    

a= max(Lista3)#Se halla el máximo elemento de la lista Lista3 y será impreso
while a in Lista3: 
   

    
    print(Lista2.pop(Lista3.index(max(Lista3))), ' sublista ordenada\
 ascendentemente más larga')
    
    Lista3.pop(Lista3.index(max(Lista3)))

# %%
#20.1
import numpy as np

while True:
    try   :
        M = eval(input('Ingrese una matriz de cualquier tamaño: '))
        
        # Comprueba que el elemento ingresado sea una lista
        if type(M) is list :
            
            # Revisara cada elemento de la matriz.
            for F in M:
                if type(F) is list:
                    
                    # Revisara cada elemento o "entrada" de cada fila
                    # y asegurara que sea un entero.
                    
                    for Entrada in F:
                        # Si no es un entero lanzara error.
                        if type(Entrada) is not int: raise Exception
            # En caso de que alguna fila no sea una lista lanzara un error
                else: raise Exception
        # En caso de que el elemento ingresado no se una lista
        # lanza un error.
        else: raise Exception
            
        # Si todo lo anterior sucede sin errores interrumpe el ciclo while.
        break
    
    except Exception:
        print('Alguno de los elementos de la matriz no cumple con \
la definicion de matriz. Revise su matriz e intentelo de nuevo.')

R90 = np.rot90(M) # R90 será la matriz rotada 90°

print(R90)

# %%
#20.2 
def Leer_matriz():
    '''
    lee una matriz que contenga listas,que sus elementos sean enteros y que
    sea de cualquier longitud
    '''
    while True:
        try:
            M= eval(input('Diigite una matriz: '))
            if type(M) is list:
                for fila in M:
                    if type(fila) is list: 
                        for entrada in fila:
                            if type(entrada) is not int:
                                raise Exception
                                # Revisara cada elemento o "entrada" de cada fila
                    # y asegurara que sea un entero. 
                    
                    else:
                        raise Exception
            else:
                raise Exception
            
            for Fila in M:
                if len(Fila) != len(M[0]) :
                    raise Exception
                    # si lo anterior no tiene errores no se rompe el ciclo 
                    
            break     
        except:
            print('Debe ser una matriz de numeros enteros con todas sus filas\
 iguales.')
            
    return M
